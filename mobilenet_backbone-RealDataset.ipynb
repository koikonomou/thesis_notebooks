# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import os
import sys
if '/opt/ros/kinetic/lib/python2.7/dist-packages' in sys.path: sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
import cv2 
from PIL import Image
from pathlib import Path
import glob

# %%
import tensorflow as tf
# tf.config.experimental.set_memory_growth((tf.config.experimental.list_physical_devices('GPU'))[0], True)
from math import pi
from sklearn.preprocessing import normalize

# %%
# Definitions
DATA_DIR = "/home/kate/catkin_ws/src/thesis/DATASETS/Dataset/"
DEPTH_FILE, RGB_FILE, SEGMENT_FILE = "depth0.png", "rgb0.png", "Segments_0.png"
NUM_SEGMENTS = 9 # 10 needed, 2 additional
SEGMENT_NAMES = ["_background_", "table", "cup", "bottle", "glass", "fork", "knife", "food", "plate"]

# Camera information
IMG_HEIGHT, IMG_WIDTH, CHANNELS = 720, 1280, 3 # Shape of the images
OUT_SHAPE = (720, 1280)

# %%
def __getRGB(thisPath): 
#     """Internal: tf-pure function to return the RGB Image of a datatpoint"""
    png = tf.io.read_file(thisPath, name="read_file_RGB")
    png = tf.image.decode_png(png, name="RGB_Decoding")
    png = tf.image.convert_image_dtype(png, tf.float32, name="RGB_RangeChange")
    png.set_shape((IMG_HEIGHT, IMG_WIDTH, 3))
    return png

def __getD(thisPath): 
#      """Internal: tf-pure function to return the Depth Image of a datatpoint"""
    D = tf.io.read_file(thisPath, name="read_file_Depth")
    D = tf.image.decode_png(D, dtype=tf.uint16, name="Depth_Decoding")
    D = tf.cast(D, tf.float32, name="Depth_uint16_to_float32")
    D = tf.math.reciprocal_no_nan(D, name="Invert_Depth")
    D.set_shape((IMG_HEIGHT, IMG_WIDTH, 1))
    return D

def __getSegments(thisPath): 
#     """Internal: tf-pure function to return the Segment Image-Set of a datatpoint"""
    S = tf.io.read_file(thisPath, name="read_file_Segments")
    S = tf.image.decode_png(S, name="Segments_Decoding")[:,:,0]
    S = tf.squeeze(S, name="Segments_Squeezing")
    S = tf.one_hot(S, NUM_SEGMENTS, name="One_Hot_Segments")
    S.set_shape((IMG_HEIGHT, IMG_WIDTH, NUM_SEGMENTS))
    S = tf.image.resize(S, size=OUT_SHAPE)
    return S
   
@tf.function

def loadDatapoint(paths):
#     """Loads a single datapoint and returns the (4+NUM_SEGMENTS+3) Channel x-Image and the label"""
    RGB = __getRGB(paths+RGB_FILE)
#     D = __getD(paths+"/"+DEPTH_FILE)
    S = __getSegments(paths+SEGMENT_FILE)
    x = tf.concat([RGB], axis=2, name="Stack_RGB_D")
    return x, S

# %%
def showDatapoint(x,y):
    """Represent a single datapoint in ipynb-readable format"""
    image, label = x, y 
    img = image.numpy()
    C = img[:,:,:3]
    #D = img[:,:,3]
    S = label
    plt.figure("Images", figsize=(5,5))
    I_C= plt.imshow(C)
    plt.title("RGB")
  #I_D=plt.imshow(D)
   #plt.title("Depth$^{-1}$")
    for i in (I_C,):#, I_D):
        i.axes.get_yaxis().set_visible(False)
        i.axes.get_xaxis().set_visible(False)
    plt.show()
    f1 = plt.figure("Segments", figsize=(30, 2))
    f1.suptitle("Segments")
    for i in range(NUM_SEGMENTS):
        s = S[:,:,i]
        plt.subplot(1,NUM_SEGMENTS,i+1)
        if i < len(SEGMENT_NAMES):
            plt.title(SEGMENT_NAMES[i])
        else: plt.title("Placeholder")
        I_S = plt.imshow(s, vmin=0, vmax=1)
        I_S.axes.get_yaxis().set_visible(False)
        I_S.axes.get_xaxis().set_visible(False)
    plt.show()

# %%
def getDataset(datasetPath, batch_size=None, batch_drop_remainder=False, cache=None, prefetch_buffer_size=tf.data.experimental.AUTOTUNE, testPercentage=20, random_seed=13):
#    """Returns the seed-defined shuffled dataset from the csv as train_set, test_set
#         Parameters:
#         datasetPath: The path to the dataset
#         batch_size: batch size to run with
#         cache: From the dataset doku: filename: 
#             A tf.string scalar tf.Tensor, representing the name of a directory on the filesystem to 
#             use for caching elements in this Dataset. If a filename is not provided, the dataset will 
#             be cached in memory.
#         prefetch_buffer_size: buffer size used in prefetching
#         testPercentage: Percentage of the data used for testing
#         random_seed: seed used by numpy to shuffle the dataset """

    DATASET_LENGTH = 99
    testPercentage = 10  # Percentage of data used for testing 
    dsSplit = int(DATASET_LENGTH*testPercentage/100.) # Number of items in training set
    paths = [datasetPath+str(i)+"/" for i in range(DATASET_LENGTH) if i!= 0]
    np.random_seed=random_seed
    np.random.shuffle(paths)
    ds = tf.data.Dataset.from_tensor_slices((paths))
    ds = ds.map(loadDatapoint, num_parallel_calls=tf.data.experimental.AUTOTUNE) 
    if cache:
        ds = ds.cache(cache)
    if batch_size:
        ds = ds.batch(batch_size, drop_remainder=batch_drop_remainder)
    if prefetch_buffer_size:
        ds = ds.prefetch(buffer_size=prefetch_buffer_size)
    return ds.skip(dsSplit), ds.take(dsSplit)

# %%
if __name__ == "__main__":
    dsTrain, dsTest = getDataset(datasetPath = 
                             DATA_DIR, 
                             batch_size=8)#, batch_drop_remainder=True, cache=None)#"~")

# %%
for i,j in dsTrain:
    showDatapoint(i[0],j[0])
    break

# %%
# y_train[:,:,:,0]= 0
# y_test[:,:,:,0]= 0

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def ourBlock (x, basename, channels=9):
  x = layers.Conv2D (channels, 1, padding='same', name = basename+"_bottleneck_conv")(x)
  x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_bottleneck_BN')(x)
  x = layers.ReLU(6., name=basename+'_bottleneck_relu')(x)

  x = layers.Conv2D (4*channels, 1, padding='same', name = basename+"_conv")(x)
  x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_BN')(x)
  x = layers.ReLU(6., name=basename+'_relu')(x)

  x = layers.DepthwiseConv2D(kernel_size=3, activation=None, use_bias=False, padding='same', name=basename+'-DW')(x)
  x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_DW_BN')(x)
  x = layers.ReLU(6., name=basename+'_DW_relu')(x)
  
  x = layers.Conv2D (channels, 1, padding='same', name = basename+"_project")(x)
  x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_project_BN')(x)
    
  return x

# %%
def downsampling_block(x, basename, channels=9):
    x = layers.Conv2D (channels, 1, padding='same', name = basename+"expand")(x)
    x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_expand_BN')(x)
    x = layers.ReLU(6., name=basename+'_expand_relu')(x)
    
    x = layers.ZeroPadding2D(padding=((1,0), (1,0)), name=basename+'_pad')(x)
    x = layers.DepthwiseConv2D(kernel_size=3, strides=(2, 2), depth_multiplier=1, activation=None, use_bias=False, padding='valid',name=basename+'_depthwise')(x)
    x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_depthwise_BN')(x)
    x = layers.ReLU(max_value=6, negative_slope=0, threshold=0, name=basename+'_depthwise_relu' )(x)

    x = layers.Conv2D (channels, 1, padding='same', name = basename+"_project")(x)
#     x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_project_BN')(x)
    return x

# %%
def conv_block(x, basename, channels):
    x = layers.Conv2D (channels, 1, padding='same', name = basename+"expand")(x)
    x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_expand_BN')(x)
    x = layers.ReLU(6., name=basename+'_expand_relu')(x)
    
    x = layers.DepthwiseConv2D(kernel_size=3, depth_multiplier=1, activation=None, use_bias=False, padding='same',name=basename+'_depthwise')(x)
    x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_depthwise_BN')(x)
    x = layers.ReLU(max_value=6, negative_slope=0, threshold=0, name=basename+'_depthwise_relu' )(x)

    x = layers.Conv2D (channels, 1, padding='same', name = basename+"_project")(x)
#     x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999, name=basename+'_project_BN')(x)
    return x

# %%
# history = model.fit(dsTrain, epochs=60)

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from keras.optimizers import Adam, RMSprop, SGD
from tensorflow import keras
from tensorflow.keras import layers

model = MobileNetV2(weights="imagenet", include_top = False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x =  model.get_layer("block_16_project_BN").output

x = layers.ReLU(max_value=None, negative_slope=0, threshold=0 )(x)
# x = layers.ZeroPadding2D(padding=((1,1), (1,1)))(x)

x = layers.DepthwiseConv2D(kernel_size=3, strides=(1,1), depth_multiplier=1, activation=None, use_bias=False, padding='same')(x)
x = layers.BatchNormalization(axis=-1, epsilon=1e-3, momentum=0.999)(x)
x = layers.ReLU(max_value=6, negative_slope=0, threshold=0 )(x)
# x = layers.ZeroPadding2D(padding=((1,1), (3,2)))(x)
x = layers.Conv2D (9, 1, padding='same', activation='relu', name = "block_18_cosdfsffnv_outpsut")(x)
x = layers.DepthwiseConv2D(kernel_size=3, strides=(2, 2), depth_multiplier=1, activation=None, use_bias=False, padding='valid',name='block_18_depthwise')(x)
# x = layers.ZeroPadding2D(padding=((1,0), (1,0)))(x)
x = layers.Conv2D (9, 1, padding='same', activation='relu', name = "block_18_conv_outpsut")(x)

x = layers.Conv2D (9, 1, padding='same', activation='relu', name = "block_18_middle_1conv_output")(x)
x = layers.Conv2D (9, 1, padding='same', activation='relu', name = "block_18_middle_2conv_output")(x)
x = layers.Conv2D (9, 1, padding='same', activation='softmax', name = "block_18_middle_3conv_output")(x)

x = ourBlock (x, "block_17")
x = layers.UpSampling2D(interpolation='bilinear', name='block_19_upto16')(x)
x = layers.ZeroPadding2D(padding=((1,0), (1,1)))(x)

x = layers.Concatenate(name="block_19_concat")([x,model.get_layer("block_14_add").output])
x = ourBlock (x, 'block_19')

x = layers.ReLU(max_value=None, negative_slope=0, threshold=0 )(x)
x = layers.DepthwiseConv2D(kernel_size=3, strides=(2, 2), depth_multiplier=1, activation=None, use_bias=False, padding='valid')(x)
x = layers.UpSampling2D(size=(2,2),interpolation='bilinear', name='block_195_upto16')(x)
x = layers.UpSampling2D(interpolation='bilinear', name='block_20_upto8')(x)
x = layers.ZeroPadding2D(padding=((1,0), (1,1)))(x)
x = layers.ZeroPadding2D(padding=((0,0), (1,1)))(x)
x = layers.Concatenate(name="block_20_concat")([x,model.get_layer("block_12_add").output])
x = ourBlock (x, 'block_20')

x = layers.UpSampling2D(interpolation='bilinear', name='block_21_upto4')(x)
x = layers.Concatenate(name="block_21_concat")([x,model.get_layer("block_4_add").output])
x = ourBlock (x, 'block_21')

x = layers.UpSampling2D(interpolation='bilinear', name='block_22_upto2')(x)
x = layers.Concatenate(name="block_22_concat")([x,model.get_layer("block_2_add").output])
x = ourBlock (x, 'block_22')

x = layers.UpSampling2D(interpolation='bilinear', name='block_23_upto1')(x)
x = layers.Concatenate(name="block_23_concat")([x,model.get_layer("expanded_conv_project_BN").output])
x = ourBlock (x, 'block_23')

x = layers.UpSampling2D(interpolation='bilinear', name='block_24_upto1')(x)
x = ourBlock (x, 'block_24', channels=9)

# x = layers.Conv2D (10, 1, padding='same', activation='softmax', name = "block_23_conv_output")(x)



model = keras.Model(inputs=model.input, outputs=x)
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.Precision()])
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 720, 1280, 3 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 360, 640, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 360, 640, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 360, 640, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 360, 640, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 360, 640, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 360, 640, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 360, 640, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 360, 640, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 360, 640, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 360, 640, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 360, 640, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 361, 641, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 180, 320, 96) 864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 180, 320, 96) 384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 180, 320, 96) 0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 180, 320, 24) 2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 180, 320, 24) 96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 180, 320, 144 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 180, 320, 144 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 180, 320, 144 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 180, 320, 144 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 180, 320, 144 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 180, 320, 144 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 180, 320, 24) 3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 180, 320, 24) 96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 180, 320, 24) 0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 180, 320, 144 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 180, 320, 144 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 180, 320, 144 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 181, 321, 144 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 90, 160, 144) 1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 90, 160, 144) 576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 90, 160, 144) 0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 90, 160, 32)  4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 90, 160, 32)  128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 90, 160, 192) 6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 90, 160, 192) 768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 90, 160, 192) 0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 90, 160, 192) 1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 90, 160, 192) 768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 90, 160, 192) 0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 90, 160, 32)  6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 90, 160, 32)  128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 90, 160, 32)  0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 90, 160, 192) 6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 90, 160, 192) 768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 90, 160, 192) 0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 90, 160, 192) 1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 90, 160, 192) 768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 90, 160, 192) 0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 90, 160, 32)  6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 90, 160, 32)  128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 90, 160, 32)  0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 90, 160, 192) 6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 90, 160, 192) 768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 90, 160, 192) 0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 91, 161, 192) 0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 45, 80, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 45, 80, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 45, 80, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 45, 80, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 45, 80, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 45, 80, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 45, 80, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 45, 80, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 45, 80, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 45, 80, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 45, 80, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 45, 80, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 45, 80, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 45, 80, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 45, 80, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 45, 80, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 45, 80, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 45, 80, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 45, 80, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 45, 80, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 45, 80, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 45, 80, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 45, 80, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 45, 80, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 45, 80, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 45, 80, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 45, 80, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 45, 80, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 45, 80, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 45, 80, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 45, 80, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 45, 80, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 45, 80, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 45, 80, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 45, 80, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 45, 80, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 45, 80, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 45, 80, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 45, 80, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 45, 80, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 45, 80, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 45, 80, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 45, 80, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 45, 80, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 45, 80, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 45, 80, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 45, 80, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 45, 80, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 45, 80, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 45, 80, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 45, 80, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 45, 80, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 45, 80, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 45, 80, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 45, 80, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 45, 80, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 45, 80, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 45, 80, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 45, 80, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 45, 80, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 45, 80, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 47, 81, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 23, 40, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 23, 40, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 23, 40, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 23, 40, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 23, 40, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 23, 40, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 23, 40, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 23, 40, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 23, 40, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 23, 40, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 23, 40, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 23, 40, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 23, 40, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 23, 40, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 23, 40, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 23, 40, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 23, 40, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 23, 40, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 23, 40, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 23, 40, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 23, 40, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 23, 40, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 23, 40, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 23, 40, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 23, 40, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 23, 40, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 23, 40, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 23, 40, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 23, 40, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 23, 40, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 23, 40, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 23, 40, 320)  0           block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 23, 40, 320)  2880        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 23, 40, 320)  1280        depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 23, 40, 320)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# block_18_cosdfsffnv_outpsut (Co (None, 23, 40, 9)    2889        re_lu_1[0][0]
# __________________________________________________________________________________________________
# block_18_depthwise (DepthwiseCo (None, 11, 19, 9)    81          block_18_cosdfsffnv_outpsut[0][0]
# __________________________________________________________________________________________________
# block_18_conv_outpsut (Conv2D)  (None, 11, 19, 9)    90          block_18_depthwise[0][0]
# __________________________________________________________________________________________________
# block_18_middle_1conv_output (C (None, 11, 19, 9)    90          block_18_conv_outpsut[0][0]
# __________________________________________________________________________________________________
# block_18_middle_2conv_output (C (None, 11, 19, 9)    90          block_18_middle_1conv_output[0][0
# __________________________________________________________________________________________________
# block_18_middle_3conv_output (C (None, 11, 19, 9)    90          block_18_middle_2conv_output[0][0
# __________________________________________________________________________________________________
# block_17_bottleneck_conv (Conv2 (None, 11, 19, 9)    90          block_18_middle_3conv_output[0][0
# __________________________________________________________________________________________________
# block_17_bottleneck_BN (BatchNo (None, 11, 19, 9)    36          block_17_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_17_bottleneck_relu (ReLU) (None, 11, 19, 9)    0           block_17_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_17_conv (Conv2D)          (None, 11, 19, 36)   360         block_17_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_17_BN (BatchNormalization (None, 11, 19, 36)   144         block_17_conv[0][0]
# __________________________________________________________________________________________________
# block_17_relu (ReLU)            (None, 11, 19, 36)   0           block_17_BN[0][0]
# __________________________________________________________________________________________________
# block_17-DW (DepthwiseConv2D)   (None, 11, 19, 36)   324         block_17_relu[0][0]
# __________________________________________________________________________________________________
# block_17_DW_BN (BatchNormalizat (None, 11, 19, 36)   144         block_17-DW[0][0]
# __________________________________________________________________________________________________
# block_17_DW_relu (ReLU)         (None, 11, 19, 36)   0           block_17_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_17_project (Conv2D)       (None, 11, 19, 9)    333         block_17_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_17_project_BN (BatchNorma (None, 11, 19, 9)    36          block_17_project[0][0]
# __________________________________________________________________________________________________
# block_19_upto16 (UpSampling2D)  (None, 22, 38, 9)    0           block_17_project_BN[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 23, 40, 9)    0           block_19_upto16[0][0]
# __________________________________________________________________________________________________
# block_19_concat (Concatenate)   (None, 23, 40, 169)  0           zero_padding2d[0][0]
#                                                                  block_14_add[0][0]
# __________________________________________________________________________________________________
# block_19_bottleneck_conv (Conv2 (None, 23, 40, 9)    1530        block_19_concat[0][0]
# __________________________________________________________________________________________________
# block_19_bottleneck_BN (BatchNo (None, 23, 40, 9)    36          block_19_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_19_bottleneck_relu (ReLU) (None, 23, 40, 9)    0           block_19_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_19_conv (Conv2D)          (None, 23, 40, 36)   360         block_19_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_19_BN (BatchNormalization (None, 23, 40, 36)   144         block_19_conv[0][0]
# __________________________________________________________________________________________________
# block_19_relu (ReLU)            (None, 23, 40, 36)   0           block_19_BN[0][0]
# __________________________________________________________________________________________________
# block_19-DW (DepthwiseConv2D)   (None, 23, 40, 36)   324         block_19_relu[0][0]
# __________________________________________________________________________________________________
# block_19_DW_BN (BatchNormalizat (None, 23, 40, 36)   144         block_19-DW[0][0]
# __________________________________________________________________________________________________
# block_19_DW_relu (ReLU)         (None, 23, 40, 36)   0           block_19_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_19_project (Conv2D)       (None, 23, 40, 9)    333         block_19_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_19_project_BN (BatchNorma (None, 23, 40, 9)    36          block_19_project[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 23, 40, 9)    0           block_19_project_BN[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 11, 19, 9)    81          re_lu_2[0][0]
# __________________________________________________________________________________________________
# block_195_upto16 (UpSampling2D) (None, 22, 38, 9)    0           depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# block_20_upto8 (UpSampling2D)   (None, 44, 76, 9)    0           block_195_upto16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 45, 78, 9)    0           block_20_upto8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 45, 80, 9)    0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# block_20_concat (Concatenate)   (None, 45, 80, 105)  0           zero_padding2d_2[0][0]
#                                                                  block_12_add[0][0]
# __________________________________________________________________________________________________
# block_20_bottleneck_conv (Conv2 (None, 45, 80, 9)    954         block_20_concat[0][0]
# __________________________________________________________________________________________________
# block_20_bottleneck_BN (BatchNo (None, 45, 80, 9)    36          block_20_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_20_bottleneck_relu (ReLU) (None, 45, 80, 9)    0           block_20_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_20_conv (Conv2D)          (None, 45, 80, 36)   360         block_20_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_20_BN (BatchNormalization (None, 45, 80, 36)   144         block_20_conv[0][0]
# __________________________________________________________________________________________________
# block_20_relu (ReLU)            (None, 45, 80, 36)   0           block_20_BN[0][0]
# __________________________________________________________________________________________________
# block_20-DW (DepthwiseConv2D)   (None, 45, 80, 36)   324         block_20_relu[0][0]
# __________________________________________________________________________________________________
# block_20_DW_BN (BatchNormalizat (None, 45, 80, 36)   144         block_20-DW[0][0]
# __________________________________________________________________________________________________
# block_20_DW_relu (ReLU)         (None, 45, 80, 36)   0           block_20_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_20_project (Conv2D)       (None, 45, 80, 9)    333         block_20_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_20_project_BN (BatchNorma (None, 45, 80, 9)    36          block_20_project[0][0]
# __________________________________________________________________________________________________
# block_21_upto4 (UpSampling2D)   (None, 90, 160, 9)   0           block_20_project_BN[0][0]
# __________________________________________________________________________________________________
# block_21_concat (Concatenate)   (None, 90, 160, 41)  0           block_21_upto4[0][0]
#                                                                  block_4_add[0][0]
# __________________________________________________________________________________________________
# block_21_bottleneck_conv (Conv2 (None, 90, 160, 9)   378         block_21_concat[0][0]
# __________________________________________________________________________________________________
# block_21_bottleneck_BN (BatchNo (None, 90, 160, 9)   36          block_21_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_21_bottleneck_relu (ReLU) (None, 90, 160, 9)   0           block_21_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_21_conv (Conv2D)          (None, 90, 160, 36)  360         block_21_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_21_BN (BatchNormalization (None, 90, 160, 36)  144         block_21_conv[0][0]
# __________________________________________________________________________________________________
# block_21_relu (ReLU)            (None, 90, 160, 36)  0           block_21_BN[0][0]
# __________________________________________________________________________________________________
# block_21-DW (DepthwiseConv2D)   (None, 90, 160, 36)  324         block_21_relu[0][0]
# __________________________________________________________________________________________________
# block_21_DW_BN (BatchNormalizat (None, 90, 160, 36)  144         block_21-DW[0][0]
# __________________________________________________________________________________________________
# block_21_DW_relu (ReLU)         (None, 90, 160, 36)  0           block_21_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_21_project (Conv2D)       (None, 90, 160, 9)   333         block_21_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_21_project_BN (BatchNorma (None, 90, 160, 9)   36          block_21_project[0][0]
# __________________________________________________________________________________________________
# block_22_upto2 (UpSampling2D)   (None, 180, 320, 9)  0           block_21_project_BN[0][0]
# __________________________________________________________________________________________________
# block_22_concat (Concatenate)   (None, 180, 320, 33) 0           block_22_upto2[0][0]
#                                                                  block_2_add[0][0]
# __________________________________________________________________________________________________
# block_22_bottleneck_conv (Conv2 (None, 180, 320, 9)  306         block_22_concat[0][0]
# __________________________________________________________________________________________________
# block_22_bottleneck_BN (BatchNo (None, 180, 320, 9)  36          block_22_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_22_bottleneck_relu (ReLU) (None, 180, 320, 9)  0           block_22_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_22_conv (Conv2D)          (None, 180, 320, 36) 360         block_22_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_22_BN (BatchNormalization (None, 180, 320, 36) 144         block_22_conv[0][0]
# __________________________________________________________________________________________________
# block_22_relu (ReLU)            (None, 180, 320, 36) 0           block_22_BN[0][0]
# __________________________________________________________________________________________________
# block_22-DW (DepthwiseConv2D)   (None, 180, 320, 36) 324         block_22_relu[0][0]
# __________________________________________________________________________________________________
# block_22_DW_BN (BatchNormalizat (None, 180, 320, 36) 144         block_22-DW[0][0]
# __________________________________________________________________________________________________
# block_22_DW_relu (ReLU)         (None, 180, 320, 36) 0           block_22_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_22_project (Conv2D)       (None, 180, 320, 9)  333         block_22_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_22_project_BN (BatchNorma (None, 180, 320, 9)  36          block_22_project[0][0]
# __________________________________________________________________________________________________
# block_23_upto1 (UpSampling2D)   (None, 360, 640, 9)  0           block_22_project_BN[0][0]
# __________________________________________________________________________________________________
# block_23_concat (Concatenate)   (None, 360, 640, 25) 0           block_23_upto1[0][0]
#                                                                  expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_23_bottleneck_conv (Conv2 (None, 360, 640, 9)  234         block_23_concat[0][0]
# __________________________________________________________________________________________________
# block_23_bottleneck_BN (BatchNo (None, 360, 640, 9)  36          block_23_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_23_bottleneck_relu (ReLU) (None, 360, 640, 9)  0           block_23_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_23_conv (Conv2D)          (None, 360, 640, 36) 360         block_23_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_23_BN (BatchNormalization (None, 360, 640, 36) 144         block_23_conv[0][0]
# __________________________________________________________________________________________________
# block_23_relu (ReLU)            (None, 360, 640, 36) 0           block_23_BN[0][0]
# __________________________________________________________________________________________________
# block_23-DW (DepthwiseConv2D)   (None, 360, 640, 36) 324         block_23_relu[0][0]
# __________________________________________________________________________________________________
# block_23_DW_BN (BatchNormalizat (None, 360, 640, 36) 144         block_23-DW[0][0]
# __________________________________________________________________________________________________
# block_23_DW_relu (ReLU)         (None, 360, 640, 36) 0           block_23_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_23_project (Conv2D)       (None, 360, 640, 9)  333         block_23_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_23_project_BN (BatchNorma (None, 360, 640, 9)  36          block_23_project[0][0]
# __________________________________________________________________________________________________
# block_24_upto1 (UpSampling2D)   (None, 720, 1280, 9) 0           block_23_project_BN[0][0]
# __________________________________________________________________________________________________
# block_24_bottleneck_conv (Conv2 (None, 720, 1280, 9) 90          block_24_upto1[0][0]
# __________________________________________________________________________________________________
# block_24_bottleneck_BN (BatchNo (None, 720, 1280, 9) 36          block_24_bottleneck_conv[0][0]
# __________________________________________________________________________________________________
# block_24_bottleneck_relu (ReLU) (None, 720, 1280, 9) 0           block_24_bottleneck_BN[0][0]
# __________________________________________________________________________________________________
# block_24_conv (Conv2D)          (None, 720, 1280, 36 360         block_24_bottleneck_relu[0][0]
# __________________________________________________________________________________________________
# block_24_BN (BatchNormalization (None, 720, 1280, 36 144         block_24_conv[0][0]
# __________________________________________________________________________________________________
# block_24_relu (ReLU)            (None, 720, 1280, 36 0           block_24_BN[0][0]
# __________________________________________________________________________________________________
# block_24-DW (DepthwiseConv2D)   (None, 720, 1280, 36 324         block_24_relu[0][0]
# __________________________________________________________________________________________________
# block_24_DW_BN (BatchNormalizat (None, 720, 1280, 36 144         block_24-DW[0][0]
# __________________________________________________________________________________________________
# block_24_DW_relu (ReLU)         (None, 720, 1280, 36 0           block_24_DW_BN[0][0]
# __________________________________________________________________________________________________
# block_24_project (Conv2D)       (None, 720, 1280, 9) 333         block_24_DW_relu[0][0]
# __________________________________________________________________________________________________
# block_24_project_BN (BatchNorma (None, 720, 1280, 9) 36          block_24_project[0][0]
# ==================================================================================================
# Total params: 1,864,056
# Trainable params: 1,830,604
# Non-trainable params: 33,452
# __________________________________________________________________________________________________

# %%
history = model.fit(dsTrain, epochs=50)
# Out:
# Epoch 1/50

# %%
metrics = model.evaluate(dsTest, verbose=0)
print("Evaluated Metrics for the Test-Set:")
for name, value in zip(model.metrics_names, metrics):
    print(f"{name}: {value}")

# %%
printX = dsTest.take(1)
predictedY = model.predict(printX)
m = np.argmax(predictedY, axis=-1)
predictedY = tf.one_hot(m, 10)
i=0
for x,y in printX:
    print("True Values")
    showDatapoint(x[i],y[i])
    print("Network results:")
    showDatapoint(x[i],predictedY[i])
